# %%
"""
PP7

Collaborators: Max Li, ChunChao Tseng, Yujie Cai

"""

# %% [markdown]
# ** Exercise 1 **
#
#
# **Part.a **
#
#
#
# $f(x,y) = \begin{bmatrix} x^{2} + y^{2} \\ e^{x + y} \end{bmatrix}$
#
# $f_1 =x^{2} + y^{2}  $
#
# $f_2 =e^{x + y}  $
#
#
# $J_1(1,1) =\begin{bmatrix}\frac{\partial f_1}{\partial x}  \frac{\partial f_1}{\partial y} \\ \frac{\partial f_2}{\partial x}  \frac{\partial f_2}{\partial y} \end{bmatrix}=\begin{bmatrix} 2x \quad 2y \\ e^{x+y} \quad e^{x+y} \end{bmatrix} = \begin{bmatrix} 2 \quad 2 \\ e^2\quad e^2\end{bmatrix}$
#
#
# ** Part.b **
#
#
#
# i.) $J_p = \begin{bmatrix} 2x \quad 2y \\ e^{x+y} \quad e^{x+y} \end{bmatrix} \begin{bmatrix} 1 \\ -2 \end{bmatrix}
# =\begin{bmatrix} 2x-4y \\ -e^{x+y} \end{bmatrix}$
#
# ii.) $J_p = \begin{bmatrix} 2x \quad 2y \\ e^{x+y} \quad e^{x+y} \end{bmatrix} \begin{bmatrix} 1 \\ 1 \end{bmatrix}
# =\begin{bmatrix} 2x+2y \\ 2e^{x+y} \end{bmatrix}$

# %% [markdown]
# ** Part.c **
#
# | trace   &ensp;| Elementary Function &ensp;| Current Value &ensp;| Elementary Function Derivative &ensp;| $\nabla_{x}$ Value &ensp;| $\nabla_{y}$ Value |
# | :---:   | :------:    | :---: | :-------:           | :---------: | :----------: |
# | $x_1$ | $x_1$ | $1$ | $\dot{x_1}$ | 1 | 1
# | $x_2$ | $x_2$ | $1$ | $\dot{x_2}$ | -2 | 1
# | $v_1$ | $x_1^2$ | $1$ | 2$\dot{x_1}$ | 2 | 2
# | $v_2$ | $x_1+x_2$ | $2$ | $\dot{x_1}$+$\dot{x_2}$ | -1 | 2
# | $v_3$ | $x_2^2$ | $1$ | 2$\dot{x_2}$ | -4 | 2
# | $f_1$ | $v_1+v_3$ | $2$ | $\dot{v_1}$+$\dot{v_3}$ | -2 | 4
# | $f_2$ | $e^{v_2}$ | $e^2$ | $\dot{v_2} e^{v_2}$ | $-e^{-1}$ | $2e^{2}$
